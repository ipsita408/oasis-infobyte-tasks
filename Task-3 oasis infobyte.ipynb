# %% [markdown]
# # CAR PREDICTION USING MACHINE LEARNING
#  - Ipsita priyadarshini

# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt  
# %matplotlib inline
import seaborn as sns
sns.set()

# %% [markdown]
# #

# %%
url="https://raw.githubusercontent.com/amankharwal/Website-data/master/CarPrice.csv"
data=pd.read_csv(url)
data
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
data.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
data.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
data_new= data.drop(["drivewheel","symboling"],axis=1)
data_new.describe()
# Out:
#            car_ID   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000   98.756585  174.049268   65.907805   53.724878
# std     59.322565    6.021776   12.337289    2.145204    2.443522
# min      1.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# std     520.680204   41.642693    0.270844    0.313597          3.972040
# min    1488.000000   61.000000    2.540000    2.070000          7.000000
# ...

# %%
data_new.drop_duplicates()
# Out:
#      car_ID                   CarName fueltype aspiration doornumber  \
# 0         1        alfa-romero giulia      gas        std        two
# 1         2       alfa-romero stelvio      gas        std        two
# 2         3  alfa-romero Quadrifoglio      gas        std        two
# 3         4               audi 100 ls      gas        std       four
# 4         5                audi 100ls      gas        std       four
# ..      ...                       ...      ...        ...        ...
# 200     201           volvo 145e (sw)      gas        std       four
# 201     202               volvo 144ea      gas      turbo       four
# 202     203               volvo 244dl      gas        std       four
# 203     204                 volvo 246   diesel      turbo       four
# 204     205               volvo 264gl      gas      turbo       four
#
#          carbody enginelocation  wheelbase  carlength  carwidth  ...  \
# ...

# %%
sns.displot(data_new['price'])

# %%
sns.displot(data_new['fueltype'])

# %%
sns.displot(data_new['carbody'])

# %%
sns.displot(data_new['enginelocation'])

# %%
sns.displot(data_new['fuelsystem'])

# %%
data_mapped=data_new.copy()
data_mapped['fueltype']=data_mapped['fueltype'].map({'gas':0,'diesel':1})
data_mapped
# Out:
#      car_ID                   CarName  fueltype aspiration doornumber  \
# 0         1        alfa-romero giulia         0        std        two
# 1         2       alfa-romero stelvio         0        std        two
# 2         3  alfa-romero Quadrifoglio         0        std        two
# 3         4               audi 100 ls         0        std       four
# 4         5                audi 100ls         0        std       four
# ..      ...                       ...       ...        ...        ...
# 200     201           volvo 145e (sw)         0        std       four
# 201     202               volvo 144ea         0      turbo       four
# 202     203               volvo 244dl         0        std       four
# 203     204                 volvo 246         1      turbo       four
# 204     205               volvo 264gl         0      turbo       four
#
#          carbody enginelocation  wheelbase  carlength  carwidth  ...  \
# ...

# %%
data_mapped1=data_mapped.copy()
data_mapped1['doornumber']=data_mapped1['doornumber'].map({'two':2,'four':4})
data_mapped1
# Out:
#      car_ID                   CarName  fueltype aspiration  doornumber  \
# 0         1        alfa-romero giulia         0        std           2
# 1         2       alfa-romero stelvio         0        std           2
# 2         3  alfa-romero Quadrifoglio         0        std           2
# 3         4               audi 100 ls         0        std           4
# 4         5                audi 100ls         0        std           4
# ..      ...                       ...       ...        ...         ...
# 200     201           volvo 145e (sw)         0        std           4
# 201     202               volvo 144ea         0      turbo           4
# 202     203               volvo 244dl         0        std           4
# 203     204                 volvo 246         1      turbo           4
# 204     205               volvo 264gl         0      turbo           4
#
#          carbody enginelocation  wheelbase  carlength  carwidth  ...  \
# ...

# %%
data_clean=data_mapped1.drop(["aspiration","carbody","enginelocation","fuelsystem","enginetype","cylindernumber"],axis=1)
data_clean
# Out:
#      car_ID                   CarName  fueltype  doornumber  wheelbase  \
# 0         1        alfa-romero giulia         0           2       88.6
# 1         2       alfa-romero stelvio         0           2       88.6
# 2         3  alfa-romero Quadrifoglio         0           2       94.5
# 3         4               audi 100 ls         0           4       99.8
# 4         5                audi 100ls         0           4       99.4
# ..      ...                       ...       ...         ...        ...
# 200     201           volvo 145e (sw)         0           4      109.1
# 201     202               volvo 144ea         0           4      109.1
# 202     203               volvo 244dl         0           4      109.1
# 203     204                 volvo 246         1           4      109.1
# 204     205               volvo 264gl         0           4      109.1
#
#      carlength  carwidth  carheight  curbweight  enginesize  boreratio  \
# ...

# %%
x=data_clean.iloc[:,2:18]
y=data_clean["price"]
x
# Out:
#      fueltype  doornumber  wheelbase  carlength  carwidth  carheight  \
# 0           0           2       88.6      168.8      64.1       48.8
# 1           0           2       88.6      168.8      64.1       48.8
# 2           0           2       94.5      171.2      65.5       52.4
# 3           0           4       99.8      176.6      66.2       54.3
# 4           0           4       99.4      176.6      66.4       54.3
# ..        ...         ...        ...        ...       ...        ...
# 200         0           4      109.1      188.8      68.9       55.5
# 201         0           4      109.1      188.8      68.8       55.5
# 202         0           4      109.1      188.8      68.9       55.5
# 203         1           4      109.1      188.8      68.9       55.5
# 204         0           4      109.1      188.8      68.9       55.5
#
#      curbweight  enginesize  boreratio  stroke  compressionratio  horsepower  \
# ...

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test= train_test_split(x,y,test_size=0.3, random_state=0)
from sklearn.linear_model import LinearRegression  
regressor = LinearRegression() 
regressor.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(x_test)
y_pred
# Out:
# array([ 6795. , 15750. , 15250. ,  5151. ,  9995. , 11199. ,  5389. ,
#         7898. , 17199. ,  6529. , 20970. , 31400.5, 10945. , 18344. ,
#         8916.5,  9989. ,  9295. , 18920. ,  7895. ,  6488. ,  9959. ,
#        15580. ,  9895. , 11549. , 15998. ,  5118. ,  6938. , 16695. ,
#         8358. ,  5499. ,  7975. , 12290. , 22018. ,  8948. ,  6849. ,
#        41315. , 11595. , 18150. ,  6377. , 45400. ,  8916.5, 17450. ,
#        34184. , 15040. , 11259. ,  7609. ,  7609. , 14869. , 11694. ,
#         8495. , 23875. ,  7099. ,  8058. , 10595. , 16503. , 18399. ,
#        10795. , 18420. ,  9960. ,  6229. ,  6479. , 15510. ])

# %%
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})  
df
# Out:
#       Actual  Predicted
# 52    6795.0     6795.0
# 181  15750.0    15750.0
# 5    15250.0    15250.0
# 18    5151.0     5151.0
# 188   9995.0     9995.0
# ..       ...        ...
# 198  18420.0    18420.0
# 143   9960.0     9960.0
# 24    6229.0     6229.0
# 30    6479.0     6479.0
# 135  15510.0    15510.0
#
# [62 rows x 2 columns]

# %%
from sklearn import metrics  
print('Mean Absolute Error:', 
      metrics.mean_absolute_error(y_test, y_pred))
# Out:
# Mean Absolute Error: 3.9753720029107026e-12
